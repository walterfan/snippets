# %%
import matplotlib.pyplot as plt
import pandas as pd
'''
Date, DataCenter, Pool, Count
"2018-08-05T00:00:00.000Z",TSJ,tsj9,12722
'''
csvFile = '/Users/yafan/Documents//workspace/backup/tel_conf_count_20180820.csv'

df = pd.read_csv(csvFile, skipinitialspace=True)

#df['timestamp'] = pd.to_datetime(df[‘Date'])
df1 = df.groupby(['Date', 'DataCenter'])['Count'].sum()
print(df1)
plt.style.use('seaborn-whitegrid')

fig = plt.figure()
#df2 = df1['timestamp']
df1.plot(kind="bar", figsize=(18, 28))

plt.show()
# Out:
# Date                      DataCenter
# 2018-08-05T00:00:00.000Z  AMS             19729
#                           JPA             12864
#                           LND             27234
#                           SIG             15512
#                           TSJ            151717
# 2018-08-06T00:00:00.000Z  AMS             19717
#                           JPA             16273
#                           LND            138487
#                           SIG             45913
#                           TSJ           1130232
# 2018-08-07T00:00:00.000Z  AMS             19765
#                           JPA             16899
#                           LND            152318
#                           SIG             52533
#                           TSJ           1274525
# 2018-08-08T00:00:00.000Z  AMS             19713
#                           JPA             17242
#                           LND            153043
#                           SIG             51475
# ...

# %%
filename = 'AMS_ELS_max_capacity.csv'
print(filename[:3])
# Out:
# AMS
