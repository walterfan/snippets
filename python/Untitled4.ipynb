# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = '/Users/yafan/Documents/workspace/webex/webex-telephony-metrics/logs/GivrDailyReporter_2018080621.csv'
df = pd.read_csv(filename, skipinitialspace=True)

df['timestamp'] =  pd.to_datetime(df['timestamp'])
df1 = df.groupby([df['timestamp'].dt.to_period('H')]).count()
df2 = df1['timestamp']
df2.plot(kind="bar")
plt.show()

mytext = 'aa\nbb\n\rcc'
aaa = "<br/>".join(mytext.splitlines())
print(type(aaa))

if type(aaa) == str:
    print(aaa)
# Out:
# <class 'str'>
# aa<br/>bb<br/><br/>cc
